# %% [markdown]
# # Auto Scout Project
# **Magnimind**
#
# **Author:** Mark
# **Date:** February 2026
# **GitHub:** [link](https://github.com/mjoslin-ai/Magnimind-Project-Auto-Scout)

# %%
import pandas as pd

# %% [markdown]
# ## Project Phases:
# ### 1. Data Cleaning:

# %%
data = pd.read_json("Auto_Scout.json")
